# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:\\Users\\Basudev\\Downloads\\blogtext.csv")
data.head(10)
# Out:
#         id gender  age              topic      sign          date  \
# 0  2059027   male   15            Student       Leo   14,May,2004
# 1  2059027   male   15            Student       Leo   13,May,2004
# 2  2059027   male   15            Student       Leo   12,May,2004
# 3  2059027   male   15            Student       Leo   12,May,2004
# 4  3581210   male   33  InvestmentBanking  Aquarius  11,June,2004
# 5  3581210   male   33  InvestmentBanking  Aquarius  10,June,2004
# 6  3581210   male   33  InvestmentBanking  Aquarius  10,June,2004
# 7  3581210   male   33  InvestmentBanking  Aquarius  10,June,2004
# 8  3581210   male   33  InvestmentBanking  Aquarius  10,June,2004
# 9  3581210   male   33  InvestmentBanking  Aquarius  09,June,2004
#
#                                                 text
# 0             Info has been found (+/- 100 pages,...
# 1             These are the team members:   Drewe...
# 2             In het kader van kernfusie op aarde...
# ...

# %%
data.shape
# Out:
# (681284, 7)

# %%
data.drop(['sign', 'date'], axis = 1, inplace = True)

# %%
data.head()
# Out:
#         id gender  age              topic  \
# 0  2059027   male   15            Student
# 1  2059027   male   15            Student
# 2  2059027   male   15            Student
# 3  2059027   male   15            Student
# 4  3581210   male   33  InvestmentBanking
#
#                                                 text
# 0             Info has been found (+/- 100 pages,...
# 1             These are the team members:   Drewe...
# 2             In het kader van kernfusie op aarde...
# 3                   testing!!!  testing!!!
# 4               Thanks to Yahoo!'s Toolbar I can ...

# %%
aggregation_functions = {'gender': 'first', 'age': 'first', 'topic': 'first', 'text' : 'sum'}
df_new = data.groupby(data['id']).aggregate(aggregation_functions)
df_new.head()
# Out:
#      gender  age       topic  \
# id
# 5114   male   25      indUnk
# 7596   male   26    Internet
# 8173   male   42      indUnk
# 8349   male   24  Consulting
# 9289   male   23   Marketing
#
#                                                    text
# id
# 5114               Slashdot raises lots of  urlLink ...
# 7596         Every day should be a half day.  Took t...
# 8173          urlLink Information Awareness Office: ...
# 8349         Ever wondered what a  urlLink Bad head,...
# 9289               testing                      with...

# %%
df_new.shape
# Out:
# (19320, 4)

# %%
df_new['text'][5114]
# Out:
# "             Slashdot raises lots of  urlLink interesting thoughts about banner ads .  The idea is to let users control the ad delivery, and even to allow users to comment on ads.                       urlLink  The Merchants of Cool  , a Frontline documentary featuring Mindjack advisory board member Douglas Rushkoff, is on PBS tonight.  Check your local listings for the time.                       urlLink ATMs dispensing music?   I don't quite see the logic in that.  I'm not entirely against paying a nominal fee for music, or any other media, but if I do have to pay for it I'd be much more likely to buy stuff from my own PC.                      My chair started squeaking a few days ago and it's driving me nuts!                      The New York Press has a  urlLink lenghty article  about the post dotcom crash scene that's worth reading.                        Francis Collins'  urlLink 10 Most Surprising Things About the Human Genome .                       urlLink FILMSPEED  has gr
# ...

# %%
df_new['text'] = df_new['text'].str.replace('[^A-Za-z]', ' ')

# %%
df_new
# Out:
#          gender  age                 topic  \
# id
# 5114       male   25                indUnk
# 7596       male   26              Internet
# 8173       male   42                indUnk
# 8349       male   24            Consulting
# 9289       male   23             Marketing
# ...         ...  ...                   ...
# 4336547    male   23  Communications-Media
# 4336651  female   25               Tourism
# 4336871    male   17            Automotive
# 4337133  female   13               Student
# 4337650    male   17                indUnk
#
#                                                       text
# id
# 5114                  Slashdot raises lots of  urlLink ...
# 7596            Every day should be a half day   Took t...
# 8173             urlLink Information Awareness Office  ...
# 8349            Ever wondered what a  urlLink Bad head ...
# 9289                  testing                      with...
# ...                                                    ...
# ...

# %%
df_new['text'] = df_new['text'].str.lower()

df_new['text'] = df_new['text'].str.strip()

df_new['text'] = df_new['text'].str.split()

# %%
df_new
# Out:
#          gender  age                 topic  \
# id
# 5114       male   25                indUnk
# 7596       male   26              Internet
# 8173       male   42                indUnk
# 8349       male   24            Consulting
# 9289       male   23             Marketing
# ...         ...  ...                   ...
# 4336547    male   23  Communications-Media
# 4336651  female   25               Tourism
# 4336871    male   17            Automotive
# 4337133  female   13               Student
# 4337650    male   17                indUnk
#
#                                                       text
# id
# 5114     [slashdot, raises, lots, of, urllink, interest...
# 7596     [every, day, should, be, a, half, day, took, t...
# 8173     [urllink, information, awareness, office, how,...
# 8349     [ever, wondered, what, a, urllink, bad, head, ...
# 9289     [testing, with, each, and, every, passing, day...
# ...                                                    ...
# ...

# %%
df_new['newtext'] = ""

# %%
def listToString(s):  
    
    # initialize an empty string 
    str1 = " " 
    
    # return string   
    return (str1.join(s)) 
        
        
# Driver code     
for i in df_new['text'].index:
    df_new['newtext'][i] = listToString(df_new['text'][i])
# Out:
# C:\Users\Basudev\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
from nltk.corpus import stopwords
stopwords = set(stopwords.words('english'))

df_new['newtext'] = df_new['newtext'].apply(lambda x: ' '.join([word for word in x.split() if word not in stopwords]))

# %%
df_new
# Out:
#          gender  age                 topic  \
# id
# 5114       male   25                indUnk
# 7596       male   26              Internet
# 8173       male   42                indUnk
# 8349       male   24            Consulting
# 9289       male   23             Marketing
# ...         ...  ...                   ...
# 4336547    male   23  Communications-Media
# 4336651  female   25               Tourism
# 4336871    male   17            Automotive
# 4337133  female   13               Student
# 4337650    male   17                indUnk
#
#                                                       text  \
# id
# 5114     [slashdot, raises, lots, of, urllink, interest...
# 7596     [every, day, should, be, a, half, day, took, t...
# 8173     [urllink, information, awareness, office, how,...
# 8349     [ever, wondered, what, a, urllink, bad, head, ...
# 9289     [testing, with, each, and, every, passing, day...
# ...                                                    ...
# ...

# %%
df_new.drop(['text'], axis = 1, inplace = True)

# %%
df_new.to_csv('la.csv', index = True)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('la.csv')
df.head()
# Out:
#      id gender  age       topic  \
# 0  5114   male   25      indUnk
# 1  7596   male   26    Internet
# 2  8173   male   42      indUnk
# 3  8349   male   24  Consulting
# 4  9289   male   23   Marketing
#
#                                              newtext
# 0  slashdot raises lots urllink interesting thoug...
# 1  every day half day took afternoon hit dentist ...
# 2  urllink information awareness office paranoid ...
# 3  ever wondered urllink bad head head crash hard...
# 4  testing every passing day hard imagine going a...

# %%
df.topic.value_counts()
# Out:
# indUnk                     6827
# Student                    5120
# Education                   980
# Technology                  943
# Arts                        721
# Communications-Media        479
# Internet                    397
# Non-Profit                  372
# Engineering                 312
# Government                  236
# Law                         197
# Consulting                  191
# Science                     184
# Marketing                   180
# BusinessServices            163
# Publishing                  150
# Advertising                 145
# Religion                    139
# Telecommunications          119
# Military                    116
# Banking                     112
# Accounting                  105
# Fashion                      98
# HumanResources               94
# Tourism                      94
# Transportation               91
# Sports-Recreation            90
# Manufacturing                87
# Architecture                 69
# ...

# %%
student = df[df['topic'] == 'Student'][:721]
education = df[df['topic'] == 'Education'][:721]
technology = df[df['topic'] == 'Technology'][:721]
arts = df[df['topic'] == 'Arts']

# %%
arts.shape
# Out:
# (721, 5)

# %%
normal_distributed_df = pd.concat([student, education, technology, arts])

# Shuffle dataframe rows
new_df = normal_distributed_df.sample(frac=1, random_state=42)

new_df.head()
# Out:
#            id  gender  age       topic  \
# 2293  2410480    male   15     Student
# 147    306435    male   24  Technology
# 4881  3353160  female   14        Arts
# 2633  2673145  female   25  Technology
# 7453  3518560  female   24   Education
#
#                                                 newtext
# 2293  feeling bored today decided change template bl...
# 147   well glad see kristin updated blog time say wa...
# 4881  hahahahahahahahahahaha weaklings orange ruling...
# 2633  luckily payday around corner damn broke make l...
# 7453  today pretty uneventful blah keeps bugging spe...

# %%
new_df.gender.value_counts()
# Out:
# male      1600
# female    1284
# Name: gender, dtype: int64

# %%
new_df.shape
# Out:
# (2884, 5)

# %%
new_df.to_csv('la.csv', index = False)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('la.csv')
df.head()
# Out:
#         id  gender  age       topic  \
# 0  2410480    male   15     Student
# 1   306435    male   24  Technology
# 2  3353160  female   14        Arts
# 3  2673145  female   25  Technology
# 4  3518560  female   24   Education
#
#                                              newtext
# 0  feeling bored today decided change template bl...
# 1  well glad see kristin updated blog time say wa...
# 2  hahahahahahahahahahaha weaklings orange ruling...
# 3  luckily payday around corner damn broke make l...
# 4  today pretty uneventful blah keeps bugging spe...

# %%
df.shape
# Out:
# (2884, 5)

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
from string import punctuation
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer #word stemmer class

# %%
lemma = WordNetLemmatizer()

# %%
words = set(nltk.corpus.words.words())

# %%
def normalizer(blogs):
    blogs = " ".join(filter(lambda x: x[0] != '@', blogs.split()))
    blogs = re.sub('[^a-zA-Z]', ' ', blogs)
    blogs = blogs.lower()
    blogs = re.sub(' +', ' ', blogs).strip()
    blogs = blogs.split()
    blogs = [word for word in blogs if not word in set(stopwords.words('english'))]
    blogs = [lemma.lemmatize(word) for word in blogs]
    
    blogs = " ".join(blogs)
    return blogs

# %%
df['normalized_text'] = df.newtext.apply(normalizer)

# %%
df.head()
# Out:
#         id  gender  age       topic  \
# 0  2410480    male   15     Student
# 1   306435    male   24  Technology
# 2  3353160  female   14        Arts
# 3  2673145  female   25  Technology
# 4  3518560  female   24   Education
#
#                                              newtext  \
# 0  feeling bored today decided change template bl...
# 1  well glad see kristin updated blog time say wa...
# 2  hahahahahahahahahahaha weaklings orange ruling...
# 3  luckily payday around corner damn broke make l...
# 4  today pretty uneventful blah keeps bugging spe...
#
#                                      normalized_text
# 0  feeling bored today decided change template bl...
# 1  well glad see kristin updated blog time say wa...
# 2  hahahahahahahahahahaha weakling orange ruling ...
# 3  luckily payday around corner damn broke make l...
# 4  today pretty uneventful blah keep bugging spen...

# %%
def remove_non_english_words(blog):
    return " ".join(w for w in nltk.wordpunct_tokenize(blog) if w.lower() in words or not w.isalpha())

# %%
df['normalized_text'] = df.normalized_text.apply(remove_non_english_words)

# %%
df.head()
# Out:
#         id  gender  age       topic  \
# 0  2410480    male   15     Student
# 1   306435    male   24  Technology
# 2  3353160  female   14        Arts
# 3  2673145  female   25  Technology
# 4  3518560  female   24   Education
#
#                                              newtext  \
# 0  feeling bored today decided change template bl...
# 1  well glad see kristin updated blog time say wa...
# 2  hahahahahahahahahahaha weaklings orange ruling...
# 3  luckily payday around corner damn broke make l...
# 4  today pretty uneventful blah keeps bugging spe...
#
#                                      normalized_text
# 0  feeling today decided change template feel fre...
# 1  well glad see time say wait weekend use time e...
# 2  weakling orange ruling poll million peach peac...
# 3  luckily payday around corner damn broke make l...
# 4  today pretty uneventful blah keep spend time k...

# %%
df.drop('newtext', axis = 1, inplace = True)
df.to_csv('la.csv', index = True)

# %%
df = pd.read_csv('la.csv')
df.drop('Unnamed: 0', axis =1, inplace = True)
df.to_csv('la.csv', index = False)
